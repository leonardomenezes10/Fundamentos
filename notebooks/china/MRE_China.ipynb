# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardomenezes10/Fundamentos/blob/main/notebooks/china/MRE_China.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

baseurl = 'https://agenciagov.ebc.com.br/noticias/tecnologia-e-telecomunicacao?b_start:int=0'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36'
}

newslinks = []
for x in range (0, 200, 20):
  r = requests.get(f'https://agenciagov.ebc.com.br/noticias/tecnologia-e-telecomunicacao?b_start:int={x}')
  soup = BeautifulSoup(r.content, 'lxml')

  newsfeed = soup.find_all('li', class_='noticia pagina-noticias')

  for news in newsfeed:
    for link in news.find_all('a', href=True):
      newslinks.append(baseurl + link['href'])

print(newslinks)
#print(len(newslinks))
# Out:
# ['https://agenciagov.ebc.com.br/noticias/tecnologia-e-telecomunicacao?b_start:int=0https://agenciagov.ebc.com.br/noticias/202603/minas-gerais-recebe-caravana-do-programa-brasil-antenado', 'https://agenciagov.ebc.com.br/noticias/tecnologia-e-telecomunicacao?b_start:int=0https://agenciagov.ebc.com.br/noticias/202603/carreta-digital-chega-ao-rio-de-janeiro-com-cursos-gratuitos-para-jovens-e-adultos', 'https://agenciagov.ebc.com.br/noticias/tecnologia-e-telecomunicacao?b_start:int=0https://agenciagov.ebc.com.br/noticias/202603/gov-br-conheca-tres-servicos-digitais-que-protegem-seus-dados-pessoais-contra-golpistas', 'https://agenciagov.ebc.com.br/noticias/tecnologia-e-telecomunicacao?b_start:int=0https://agenciagov.ebc.com.br/noticias/202603/parece-real-mas-pode-ser-golpe', 'https://agenciagov.ebc.com.br/noticias/tecnologia-e-telecomunicacao?b_start:int=0https://agenciagov.ebc.com.br/noticias/202603/programa-lideragov-5-0-conquista-primeiro-lugar-no-premio-conexao-inova', 'https://agencia
# ...

# %%
import requests
from bs4 import BeautifulSoup

baseurl = 'https://www.fmprc.gov.cn/eng/gjhdq_665435/3447_665449/3473_665008/3475_665012/index.html'

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Safari/537.36'
}

newslinks = []
for x in range (1, 11):
  r = requests.get(f'https://www.fmprc.gov.cn/eng/gjhdq_665435/3447_665449/3473_665008/3475_665012/index_{x}.html')
  soup = BeautifulSoup(r.content, 'lxml')

  newsfeed = soup.find_all('div', class_='news_list')

  for news in newsfeed:
    for link in news.find_all('a', href=True):
      newslinks.append(baseurl + link['href'])

#testlink = 'https://www.fmprc.gov.cn/eng/gjhdq_665435/3447_665449/3473_665008/3475_665012/202508/t20250807_11684085.html'

for links in newslinks:
  r = requests.get(links, headers=headers)
  soup = BeautifulSoup(r.content, 'lxml')
  #if the title text had a space before/after it, just type "text.strip()" and it should fix it
  name = soup.find('div', class_='news_header_title').text
  data = soup.find('span', class_='xltime').text
  #content = soup.find_all('p', style="text-indent: 0px;") #.text doesn't work
  content = soup.find('div', class_='view_dedault _default TRS_UEDITOR trs_paper_default trs_web').text
  mfanews = {
      'name': name,
      'data': data,
      'content': content
  }
  print(mfanews)

#print(name)
#print(data)
#print(content)
#print(soup.find('div', class_='view_dedault _default TRS_UEDITOR trs_paper_default trs_web').text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_203/1867215977.py in <cell line: 0>()
#      28   #data = soup.find('span', class_='xltime').text
#      29   #content = soup.find_all('p', style="text-indent: 0px;") #.text doesn't work
# ---> 30   content = soup.find('div', class_='view_dedault _default TRS_UEDITOR trs_paper_default trs_web').text
#      31   mfanews = {
#      32       'name': name,
#
# AttributeError: 'NoneType' object has no attribute 'text'
