# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardomenezes10/Fundamentos/blob/main/notebooks/brics/BRICS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importação e Instalação

# %%
# !pip install tinydb
# Out:
# Collecting tinydb
#   Downloading tinydb-4.8.2-py3-none-any.whl.metadata (6.7 kB)
# Downloading tinydb-4.8.2-py3-none-any.whl (24 kB)
# Installing collected packages: tinydb
# Successfully installed tinydb-4.8.2

# %%
# programas/bibliotecas utilizados no script/codigo
import httpx # Responsável pelas requisições web
from bs4 import BeautifulSoup # Responsável por realizar o web scraping (coletar os dados)
from tinydb import TinyDB, Query

# %% [markdown]
# ## Criação do banco json

# %%
def inserir_no_banco(BRICSBR_NEWS, link_news):
  arquivo_banco_dados = "nota_brics.json"
  db = TinyDB(arquivo_banco_dados)


  # Evitar dados repetidos no banco
  Buscar = Query()
  verificar_link = db.contains(Buscar.link == link_news)

  if not verificar_link:
    print("Inserindo nova informação no banco")
    db.insert(BRICSBR_NEWS)
  else:
    print("Link já existe no banco. Esta informação não será inserida novamente")

# %%
# !pip3 install httpx
# Out:
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx) (3.15)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx) (0.16.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx) (4.15.0)

# %%
# !pip3 install selectolax
# Out:
# Collecting selectolax
#   Downloading selectolax-0.4.10-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.2 kB)
# Downloading selectolax-0.4.10-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 25.2 MB/s eta 0:00:00
# Installing collected packages: selectolax
# Successfully installed selectolax-0.4.10

# %%
import httpx
from selectolax.parser import HTMLParser

url = 'https://brics.br/pt-br/noticias?page_bd598097_8f1d_4f8b_ac9b_d79582ac4549=1'
headers = {
    'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36",
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
}

resp = httpx.get(url, headers=headers)
html = HTMLParser(resp.text)

news = html.css("div.row ul a")
print(news)
# Out:
# []

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import httpx

paginas = ["https://brics.br/en/news?page_5c7ab9e1_1006_4ccb_8ef8_b11c36ab6309=1"]

def acessa_pagina (link):
  print (f"Estamos na pagina:{link}")

  # Define headers para a requisição, simulando um navegador
  headers = {
      'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36",
      'Accept-Language': 'en-US,en;q=0.9',
      'Accept-Encoding': 'gzip, deflate, br',
      'Connection': 'keep-alive',
  }

  timeout = httpx.Timeout(connect=20.0, read=30.0, write=20.0, pool=10.0)
  pag_web = httpx.get(link, headers=headers, timeout=timeout)
  bs = BeautifulSoup(pag_web, "html.parser")
  return bs

# loop for
# beautifulsoap >> find e find_all

for pagina in paginas:
  pagina_inteira = acessa_pagina(pagina)
  lista_noticias = pagina_inteira.find("div", attrs={"class": "twelve wide computer twelve wide mobile twelve wide tablet column"}).find_all("div")
  print(lista_noticias)
  # for noticia in lista_noticias:
  #   # titulo
  #   try:
  #     titulo = noticia.find("h2", attrs={"class": "tileHeadline"}).text.strip()
  #     print(titulo)
  #   except:
  #       titulo = ""

# url = 'https://brics.br/en/news?page_5c7ab9e1_1006_4ccb_8ef8_b11c36ab6309=1'
# page = requests.get(url)
# soup = BeautifulSoup(page.text, 'html.parser')
# soup.find('a', class_= 'item')
# #print(soup)

# title = soup.find('div', class_= 'title review-state-published')
# print(title)

# r = requests.get(url)
# soup = BeautifulSoup(r.content, 'lxml')
# title = soup.find('div', class_='news_header').find('div', class_='news_header_title').text
# Out:
# Estamos na pagina:https://brics.br/en/news?page_5c7ab9e1_1006_4ccb_8ef8_b11c36ab6309=1
# [<div class="search-wrapper"><div class="search-input"><div class="ui fluid input"><input id="5c7ab9e1-1006-4ccb-8ef8-b11c36ab6309-searchtext" placeholder="Search" type="text" value=""/></div><div class="search-input-actions"></div></div><button class="ui primary button">Search</button></div>, <div class="search-input"><div class="ui fluid input"><input id="5c7ab9e1-1006-4ccb-8ef8-b11c36ab6309-searchtext" placeholder="Search" type="text" value=""/></div><div class="search-input-actions"></div></div>, <div class="ui fluid input"><input id="5c7ab9e1-1006-4ccb-8ef8-b11c36ab6309-searchtext" placeholder="Search" type="text" value=""/></div>, <div class="search-input-actions"></div>, <div class="search-results-count-sort"><h4 class="search-details"> <!-- -->Search results<!-- -->: </h4><div class="sort-views-wrapper"></div></div>, <div class="sort-views-wrapper"></div>, <div class="emptyListing"><div class="ui active transition visible inverted dimmer"><div class="content"><div class="ui small indeterminate text loader">Loading</div></div></div></div>, <div class="ui active transition visible inverted dimmer"><div class="content"><div class="ui small indeterminate text loader">Loading</div></div></div>, <div class="content"><div class="ui small indeterminate text loader">Loading</div></div>, <div class="ui small indeterminate text loader">Loading</div>]
