# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardomenezes10/Fundamentos/blob/main/notebooks/encontro01_2026_lantri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Library and Programs
import httpx #web requests
from bs4 import BeautifulSoup #responsable to do the web scraping (data colection)

# %%
import requests
from bs4 import BeautifulSoup

page_to_scrape = requests.get("https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0")
soup = BeautifulSoup(page_to_scrape.text, "html.parser")
title = soup.find_all("span", attrs={"class": "tileContent"})
data = soup.find_all("span", attrs={"class": "icon-day"})

for tileContent, icon_date in zip(title, data):
    print(tileContent.text + " - " + icon_date.text)

# %%
import requests
from bs4 import BeautifulSoup

pagina = requests.get("https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0")
titulos = BeautifulSoup(pagina.text, "html.parser")

todos_titulos = titulos.find_all("span", attrs={"class": "tileContent"})

for titulo in todos_titulos:
    print(div)

# %%
from tinydb import TinyDB, Query

def inserir_no_banco(dados, link_noticia):
  arquivo_banco_dados = "nota_mre.json"
  db = TinyDB(arquivo_banco_dados)

# Evitar dados repetidos no banco
  Buscar = Query()
  verificar_link = db.contains(Buscar.link == link_noticia)

  if not verificar_link:
    print("Inserindo nova informação no banco")
    db.insert(dados)
  else:
    print("Link já existe no banco. Esta informação não será inserida novamente")

# %%
####################################################################
import httpx #web requests
from bs4 import BeautifulSoup #responsable to do the web scraping (data colection)

# Variável e tipos de dados (string, lista, numero)
paginas = ["https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0",
          "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=30",
          "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=60",
          "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=90"]

def acessa_pagina (link):
  print (f"Estamos na pagina:{link}")
  pag_web = httpx.get(link, timeout=10.0)
  bs = BeautifulSoup(pag_web.text, "html.parser")
  return bs

# loop for
# beautifulsoap >> find e find_all
for pagina in paginas: # percorre cada pagina da string paginas
  pagina_inteira = acessa_pagina(pagina) # essa variavel esta armazenando o html da pagina (pagina inteira)
  lista_noticias = pagina_inteira.find("div", attrs={"id": "content-core"}).find_all("article") # esta variavel string cria uma lista do elemento desejado (daqui em diante o codigo ira considerar apenas o que esta dentro do parametro que passamos)
  for noticia in lista_noticias: # aqui o for percorre o elementos da lista anterior, entrando em cada uno dos intens achados pelo find
    #TÍTULO DA PÁGINA
    titulo = noticia.find(attrs={"class": "tileHeadline"}).text.strip()
    print(titulo)

    #LINK DA NOTÍCIA
    link_noticia = noticia.a["href"]
    print(link_noticia)

    #DATA DA NOTÍCIA
    data = noticia.find(attrs={"class": "summary-view-icon"}).text.strip()
    print(data)

    #HORÁRIO DA NOTÍCIA
    #hora = noticia.find("i", attrs={"class": "icon-hour"})
    #print(hora)

    #NÚMERO NOTA
    numero_da_nota = noticia.find("span", attrs={"class": "subtitle"}).text.strip()

    # o recurso .text.strip() retira a tag html deixando so o texto
    # note que a nota no site é tipo: nota de imprensa nº 100, mas o que interessa mais é o numero mesmo, nao a frase completa. Vamos resolver isso abaixo
    #num_nota = numero_da_nota.replace("NOTA À IMPRENSA Nº ", "").replace("NOTA À IMPRENSA Nº", "").strip()
    #num_nota = numero_da_nota[19:]
    #print(num_nota)
    print (numero_da_nota)
    print("###")
    print(" ")

    conteudo = acessa_pagina(link_noticia)
    paragrafo = conteudo.find("div", attrs={"property": "rnews:articleBody"}).find_all("p")
    lista_paragrafo = []
    for paragrafo in paragrafo:
      print(paragrafo.text)
      lista_paragrafo.append(paragrafo.text)
    print(lista_paragrafo)

    dados = {
        "titulo": titulo,
        "link": link_noticia,
        "data": data,
        "numero_da_nota": numero_da_nota,
        "paragrafo": lista_paragrafo
    }

    inserir_no_banco(dados, link_noticia)

    # data
    # horário
    # paragrafos
# Out:
# Estamos na pagina:https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0
# Ataques à Força Interina das Nações Unidas e contra jornalistas no Líbano
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/ataques-a-forca-interina-das-nacoes-unidas-e-contra-jornalistas-no-libano
# 01/04/2026
# NOTA À IMPRENSA Nº 114
# ###
#
# Estamos na pagina:https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/ataques-a-forca-interina-das-nacoes-unidas-e-contra-jornalistas-no-libano
# ...

# %%
# !pip install tinydb

# %%
#Library and Programs
import httpx #web requests
from bs4 import BeautifulSoup #responsable to do the web scraping (data colection)
# Variável e tipos de dados (string, lista, numero)
paginas = ["https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0",
          "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=30",
          "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=60",
          "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=90"]

def acessa_pagina (link):
  print (f"Estamos na pagina:{link}")
  pag_web = httpx.get(link)
  bs = BeautifulSoup(pag_web, "html.parser")
  return bs

# loop for
# beautifulsoap >> find e find_all
for pagina in paginas:
  pagina_inteira = acessa_pagina(pagina)
  lista_noticias = pagina_inteira.find("div", attrs={"id": "content-core"}).find_all("article")
  for noticia in lista_noticias:
    # titulo
    titulo = noticia.find("h2", attrs={"class": "tileHeadline"}).text.strip()
    print(titulo)
    #link
    link_noticia = noticia.a["href"]
    print(link_noticia)
    # numero da nota - exemplo: NOTA À IMPRENSA Nº 72
    # numero da nota - exemplo: NOTA À IMPRENSA N° 590
    num_nota = noticia.find("span", attrs={"class": "subtitle"}).text.strip()
    # print(num_nota)
    # num_nota = noticia.find(attrs={"class": "subtitle"}).text.strip()
    num_nota = num_nota.replace("NOTA À IMPRENSA N°", "").replace("NOTA À IMPRENSA Nº", "").strip()
    print(num_nota)
    print("###")
    # data
    # horário
    #data_hora = noticia.find_all("span",attrs={"class": "summary-view-icon"})
    #data= data_hora[0].text.strip()
    #hora = data_hora[1].text.strip()
    #print(data)
    #print(hora)
    conteudo = acessa_pagina (link_noticia)
    paragrafos = conteudo.find("div", attrs={"property":"rnews:articleBody"}).find_all("p")
    lista_paragrafos = []
    for paragrafo in paragrafos:
      lista_paragrafos.append(paragrafo.text.strip())
    print(lista_paragrafos)

    #paragrafos
    data_element = noticia.find("i", attrs={"class": "icon-day"})
    if data_element:
      data = data_element.parent.text.strip()
      print(data)
    else:
      print("Data não encontrada")

    horario_element = noticia.find("i", attrs={"class": "icon-hour"})
    if horario_element:
      horario = horario_element.parent.text.strip()
      print(horario)
    else:
      print("Horário não encontrado")
  # paragrafos
# Out:
# Estamos na pagina:https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0
# Relatos de mortes na fronteira entre Colômbia e Equador
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/relatos-de-mortes-na-fronteira-entre-colombia-e-equador-1
# 88
# ###
# Estamos na pagina:https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/relatos-de-mortes-na-fronteira-entre-colombia-e-equador-1
# ['O Governo brasileiro manifesta sua grave preocupação com relatos de mortes, de origem ainda não esclarecida, na zona fronteiriça entre Colômbia e Equador.', 'Ao lamentar a perda de vidas humanas, o Governo brasileiro insta as partes envolvidas à moderação, com vistas a buscar solução pacífica para a controvérsia.', 'O Brasil coloca-se à disposição para apoiar esforços de diálogo, com vistas à preservação da paz e da segurança na região.']
# 18/03/2026
# 09h47
# ...

# %%
import requests

lista = []

for x in range(0,150,20):
    paginacao = f'https://www.gov.br/inep/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?no_start:int={x}'
    r = requests.get(paginacao)
    lista.append(paginacao)

print(lista)
# Out:
# ['https://www.gov.br/inep/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?no_start:int=0', 'https://www.gov.br/inep/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?no_start:int=20', 'https://www.gov.br/inep/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?no_start:int=40', 'https://www.gov.br/inep/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?no_start:int=60', 'https://www.gov.br/inep/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?no_start:int=80', 'https://www.gov.br/inep/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?no_start:int=100', 'https://www.gov.br/inep/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?no_start:int=120', 'https://www.gov.br/inep/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?no_start:int=140']

# %%
#essa função recebe o URL_base, Páginas (início e fim), e intervalos de paginação, e retorna a lista de paginação
def montar_links(url, pagina_inicial, pagina_final, intervalo):
    lista_paginas = []
    numeracao = pagina_final
    while numeracao >= pagina_inicial:
        link_pagina = url.format(numeracao=numeracao)
        lista_paginas.append(link_pagina)
        numeracao = numeracao - intervalo
    return lista_paginas


url = "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int={numeracao}"
lista_paginas = montar_links(url, 0, 500, 20)
print(lista_paginas)

# %%
age = ""
while True:
  age_input_str = input("Enter your age: ")
  if age_input_str == "":
    print("You did not enter your age. Please try again.")
    continue
  if not age_input_str.isdigit():
    print("Your age must contain only digits. Please try again.")
    continue
  age_int = int(age_input_str)
  if age_int < 0:
    print("Your age cannot be negative. Please try again.")
    continue
  age = age_int
  break
print(f"Your age is {age} years old.")

# %%
name = "" # Inicializa name como string vazia para garantir que o loop execute - Initialize name as an empty string to ensure that loop executes
while name == "":
  name = input("Enter your name: ")
  if name == "": # Verifica se o nome ainda está vazio após o input - Checks if the name is still empty after input
    print("You did not type in your name. Please try again.")

print(f"Hello {name}")

# %%
age = int(input("How old are you?: "))

if age >= 100: print("You are too old")
elif age >= 18:
  print("You are an adult")
  print("You can vote")
  print("You can drive")
elif age < 0: print("You are not born yet")
else: print("You are not an adult")

# %%
import httpx #web requests
from bs4 import BeautifulSoup #responsable to do the web scraping

# Lista de páginas para a Agência Gov
paginas = ["https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=0",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=20",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=40",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=60"]

def acessa_pagina(link):
  print(f"Estamos na pagina: {link}")
  try:
    pag_web = httpx.get(link, timeout=10.0)
    bs = BeautifulSoup(pag_web.text, "html.parser")
    return bs
  except Exception as e:
    print(f"Erro ao acessar {link}: {e}")
    return None

for pagina in paginas:
  pagina_inteira = acessa_pagina(pagina)
  if not pagina_inteira: continue

  # Na Agência Gov, as notícias ficam dentro de uma div com id='content-core' ou similar.
  # Vamos buscar as tags <article> diretamente para ser mais seguro.
  lista_noticias = pagina_inteira.find_all("article")

  for noticia in lista_noticias:
    # TÍTULO
    titulo_tag = noticia.find(attrs={"class": "titulo-noticia"})
    if titulo_tag:
        titulo = titulo_tag.text.strip()
        print(f"Título: {titulo}")

        # LINK
        #link_noticia = noticia.find("a")["href"]
        #print(f"Link: {link_noticia}")

        # DATA E HORÁRIO
        # No site da Agência Gov, data e hora costumam estar em spans com a classe 'data'
        #info_data = noticia.find("span", attrs={"class": "data"})
        #if info_data:
            #print(f"Data/Hora: {info_data.text.strip()}")
        #else:
            #print("Data/Hora não encontrada")

        #print("###\n")
# Out:
# Estamos na pagina: https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=0
# Título: Brasil passa a presidência do Brics para a Índia
# Estamos na pagina: https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=20
# Título: Líderes do Brics defendem multilateralismo e reforma da ONU em declaração da Cúpula
# Estamos na pagina: https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=40
# Título: Fórum Empresarial do Brics debate avanço da cooperação diante dos desafios globais
# Estamos na pagina: https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=60
# Título: Alckmin: desafios do Brics passam pela atuação dos parlamentos

# %%
import httpx #web requests
from bs4 import BeautifulSoup #responsable to do the web scraping (data colection)

# Variável e tipos de dados (string, lista, numero)
paginas = ["https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=0",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=20",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=40",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=60"]

def acessa_pagina (link):
  print (f"Estamos na pagina:{link}")
  pag_web = httpx.get(link, timeout=10.0)
  bs = BeautifulSoup(pag_web.text, "html.parser")
  return bs

# loop for
# beautifulsoap >> find e find_all
for pagina in paginas: # percorre cada pagina da string paginas
  pagina_inteira = acessa_pagina(pagina) # essa variavel esta armazenando o html da pagina (pagina inteira)
  lista_noticias = pagina_inteira.find("div", attrs={"id": "content"}).find_all("article") # esta variavel string cria uma lista do elemento desejado (daqui em diante o codigo ira considerar apenas o que esta dentro do parametro que passamos)
  for noticia in lista_noticias: # aqui o for percorre o elementos da lista anterior, entrando em cada uno dos intens achados pelo find
    #TÍTULO DA PÁGINA
    titulo = noticia.find(attrs={"class": "titulo-noticia"}).text.strip()
    print(titulo)

    #LINK DA NOTÍCIA
    #link_noticia = noticia.a["href"]
    #print(link_noticia)

    #DATA DA NOTÍCIA
    #data = noticia.find(attrs={"class": "summary-view-icon"}).text.strip()
    #print(data)

    #HORÁRIO DA NOTÍCIA


    #NÚMERO NOTA
    numero_da_nota = noticia.find("span", attrs={"class": "subtitle"}).text.strip()
    # o recurso .text.strip() retira a tag html deixando so o texto
# Out:
# Estamos na pagina:https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_314/1027970993.py in <cell line: 0>()
#      18 for pagina in paginas: # percorre cada pagina da string paginas
#      19   pagina_inteira = acessa_pagina(pagina) # essa variavel esta armazenando o html da pagina (pagina inteira)
# ---> 20   lista_noticias = pagina_inteira.find("div", attrs={"id": "content"}).find_all("article") # esta variavel string cria uma lista do elemento desejado (daqui em diante o codigo ira considerar apenas o que esta dentro do parametro que passamos)
#      21   for noticia in lista_noticias: # aqui o for percorre o elementos da lista anterior, entrando em cada uno dos intens achados pelo find
#      22     #TÍTULO DA PÁGINA
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
