# %% [markdown]
# <a href="https://colab.research.google.com/github/leonardomenezes10/Fundamentos/blob/main/notebooks/encontro01_2026_lantri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Library and Programs
import httpx #web requests
from bs4 import BeautifulSoup #responsable to do the web scraping (data colection)

# %%
import time

#https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa
#https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0
#https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=30
#https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=60

#Variável = Lista["String"]
paginas = ["https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0" ,
        "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=30" ,
        "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=60" ,
        "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=90"]

def acessa_pagina(link):
  print(f" We are on the page {link}")
  try:
    page_web = httpx.get(link, timeout=10) # Added timeout
    bs = BeautifulSoup(page_web.text , "html.parser")
    return bs
  except httpx.RemoteProtocolError as e:
    print(f"Error accessing page {link}: {e}. Skipping this page.")
    return None
  except httpx.ConnectError as e:
    print(f"Connection error accessing page {link}: {e}. Skipping this page.")
    return None
  except Exception as e:
    print(f"An unexpected error occurred accessing page {link}: {e}. Skipping this page.")
    return None

#loop for
# Beautifulsoup >> find_all
for pagina in paginas:
     pagina_inteira = acessa_pagina(pagina)
     if pagina_inteira: # Check if pagina_inteira is not None
       lista_noticias = pagina_inteira.find("div", attrs={"id": "content-core"}).find_all("article")
       for noticia in lista_noticias:
           titulo = noticia.find(attrs={"class": "tileHeadline"}).text.strip()
           print(titulo)
           link_noticia = noticia.a['href']
           print(link_noticia)
           num_nota = noticia.find("span", attrs={"class": "subtitle"}).text.strip()
           #num_nota = noticia.find(attrs={"class": "subtitle"}).text.strip()
           #num_nota = noticia.find(attrs={"class": "tileContent"}).text.strip()
           #num_nota = noticia.find("span", class_="subtitle").text.strip()

           num_nota = num_nota.replace("NOTA À IMPRENSA Nº: ", "")
           #num_nota = num_nota[-4:]
           print(num_nota)

           #data = noticia.find("span", attrs={"class": "summary-view-icon"}).text.strip
           #print(data)

           print("###")
     time.sleep(2) # Added a 2-second delay between page requests
# Out:
#  We are on the page https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0
# Endosso do Brasil à Declaração para Triplicar a Energia Nuclear até 2050 — Nota Conjunta MRE/MME
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/endosso-do-brasil-a-declaracao-internacional-em-apoio-a-meta-global-de-triplicar-a-geracao-de-energia-nuclear-ate-2050-nota-conjunta-mre-mme
# NOTA À IMPRENSA Nº 78
# ###
# Aberturas de mercado para o Brasil na Nova Zelândia e na Turquia – Nota Conjunta MRE/Mapa
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/aberturas-de-mercado-para-o-brasil-na-nova-zelandia-e-na-turquia-2013-nota-conjunta-mre-mapa
# NOTA À IMPRENSA Nº 77
# ###
# Atos adotados por ocasião da visita do Presidente da África do Sul - Brasília, 9/3/2026
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/atos-adotados-por-ocasiao-da-visita-do-presidente-da-africa-do-sul-brasilia-9-3-2026
# NOTA À IMPRENSA Nº 76
# ###
# Comunicado Conjunto por ocasião da visita do Presidente da República da África do Sul, Cyril Ramaphosa, à República Federativa do Brasil - 9/3/26
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/assinatura-de-acordo-de-paz-entre-ruanda-e-republica-democratica-do-congo
# NOTA À IMPRENSA Nº 576
# ###
# Inclusão de Araguaína (TO) e Passo Fundo (RS) na Rede de Cidades de Aprendizagem da UNESCO
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/inclusao-de-araguaina-to-e-passo-fundo-rs-na-rede-de-cidades-de-aprendizagem-da-unesco
# NOTA À IMPRENSA Nº 575
# ###
# Avanço na conservação internacional do pau-brasil — Nota Conjunta MRE/MMA/MinC
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/avanco-na-conservacao-internacional-do-pau-brasil-nota-conjunta-mre-mma-minc
# NOTA À IMPRENSA Nº 574
# ###
# Inscrição de sítios brasileiros na Lista de Proteção Reforçada da Convenção para a Proteção de Bens Culturais em Situação de Conflito Armado
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/inscricao-de-sitios-brasileiros-na-lista-de-protecao-reforcada-da-convencao-para-a-protecao-de-bens-culturais-em-situacao-de-conflito-armado
# NOTA À IMPRENSA Nº 573
# ###

# %%
import requests
from bs4 import BeautifulSoup

page_to_scrape = requests.get("http://quotes.toscrape.com")
soup = BeautifulSoup(page_to_scrape.text, "html.parser")
quotes = soup.find_all("span", attrs={"class": "text"})
authors = soup.find_all("small", attrs={"class": "author"})

for quote, author in zip(quotes, authors):
    print(quote.text + " - " + author.text)

# %%
import requests
from bs4 import BeautifulSoup

page_to_scrape = requests.get("https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0")
soup = BeautifulSoup(page_to_scrape.text, "html.parser")
title = soup.find_all("span", attrs={"class": "tileContent"})
data = soup.find_all("span", attrs={"class": "icon-day"})

for tileContent, icon_date in zip(title, data):
    print(tileContent.text + " - " + icon_date.text)

# %%
import requests
from bs4 import BeautifulSoup

pagina = requests.get("https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0")
titulos = BeautifulSoup(pagina.text, "html.parser")

todos_titulos = titulos.find_all("span", attrs={"class": "tileContent"})

for titulo in todos_titulos:
    print(div)

# %%
import httpx #web requests
from bs4 import BeautifulSoup #responsable to do the web scraping (data colection)

# Variável e tipos de dados (string, lista, numero)
paginas = ["https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0",
          "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=30",
          "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=60",
          "https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=90"]

def acessa_pagina (link):
  print (f"Estamos na pagina:{link}")
  pag_web = httpx.get(link, timeout=10.0)
  bs = BeautifulSoup(pag_web.text, "html.parser")
  return bs

# loop for
# beautifulsoap >> find e find_all
for pagina in paginas: # percorre cada pagina da string paginas
  pagina_inteira = acessa_pagina(pagina) # essa variavel esta armazenando o html da pagina (pagina inteira)
  lista_noticias = pagina_inteira.find("div", attrs={"id": "content-core"}).find_all("article") # esta variavel string cria uma lista do elemento desejado (daqui em diante o codigo ira considerar apenas o que esta dentro do parametro que passamos)
  for noticia in lista_noticias: # aqui o for percorre o elementos da lista anterior, entrando em cada uno dos intens achados pelo find
    #TÍTULO DA PÁGINA
    titulo = noticia.find(attrs={"class": "tileHeadline"}).text.strip()
    print(titulo)

    #LINK DA NOTÍCIA
    link_noticia = noticia.a["href"]
    print(link_noticia)

    #DATA DA NOTÍCIA
    data = noticia.find(attrs={"class": "summary-view-icon"}).text.strip()
    print(data)

    #HORÁRIO DA NOTÍCIA
    horario = noticia.find("i", attrs={"class": "icon-hour"}).text.strip()
    print(horario)

    #NÚMERO NOTA
    #numero_da_nota = noticia.find("span", attrs={"class": "subtitle"}).text.strip()

    # o recurso .text.strip() retira a tag html deixando so o texto
    # note que a nota no site é tipo: nota de imprensa nº 100, mas o que interessa mais é o numero mesmo, nao a frase completa. Vamos resolver isso abaixo
    num_nota = numero_da_nota.replace("NOTA À IMPRENSA Nº ", "").replace("NOTA À IMPRENSA Nº", "").strip()
    num_nota = numero_da_nota[19:]
    #print(numero_da_nota)
    print (num_nota)
    print("###")
    print(" ")

    # data
    # horário
    # paragrafos
# Out:
# Estamos na pagina:https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/notas-a-imprensa?b_start:int=0
# Endosso do Brasil à Declaração para Triplicar a Energia Nuclear até 2050 — Nota Conjunta MRE/MME
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/endosso-do-brasil-a-declaracao-internacional-em-apoio-a-meta-global-de-triplicar-a-geracao-de-energia-nuclear-ate-2050-nota-conjunta-mre-mme
# 10/03/2026
#
# 19
# ###
#
# Aberturas de mercado para o Brasil na Nova Zelândia e na Turquia – Nota Conjunta MRE/Mapa
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/aberturas-de-mercado-para-o-brasil-na-nova-zelandia-e-na-turquia-2013-nota-conjunta-mre-mapa
# 10/03/2026
#
# 19
# ###
#
# Atos adotados por ocasião da visita do Presidente da África do Sul - Brasília, 9/3/2026
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/atos-adotados-por-ocasiao-da-visita-do-presidente-da-africa-do-sul-brasilia-9-3-2026
# 09/03/2026
#
# 19
# ###
#
# Comunicado Conjunto por ocasião da visita do Presidente da República da África do Sul, Cyril Ramaphosa, à República Federativa do Brasil - 9/3/26
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/comunicado-conjunto-por-ocasiao-da-visita-do-presidente-da-republica-da-africa-do-sul-cyril-ramaphosa-a-republica-federativa-do-brasil-9-3-26
# 09/03/2026
#
# 19
# ###
#
# Visita de Estado do Presidente da República da África do Sul, Cyril Ramaphosa – Brasília, 09/03/2026
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/visita-de-estado-do-presidente-da-republica-da-africa-do-sul-cyril-ramaphosa-2013-brasilia-09-03-2026
# 06/03/2026
#
# 19
# ###
#
# Bicentenário das relações entre o Brasil e o Reino da Suécia
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/bicentenario-das-relacoes-entre-o-brasil-e-o-reino-da-suecia
# 05/03/2026
#
# 19
# ###
#
# Atos adotados por ocasião da visita do Ministro dos Negócios Estrangeiros da Nova Zelândia - Brasília - 4/3/2026
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/atos-adotados-por-ocasiao-da-visita-do-ministro-dos-negocios-estrangeiros-da-nova-zelandia-brasilia-4-3-2026
# 04/03/2026
#
# 19
# ###
#
# Visita do Ministro de Negócios Estrangeiros da Nova Zelândia, Winston Peters – Brasília, 04 a 06 de março de 2026
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa/visita-do-ministro-de-negocios-estrangeiros-da-nova-zelandia-winston-peters-2013-brasilia-04-a-06-de-marco-de-2026
# 04/03/2026
#
# 19
# ###
#
# Abertura de mercado para carnes bovina e de aves do Brasil nas Ilhas Salomão - Nota Conjunta MRE/MAPA
# https://www.gov.br/mre/pt-br/canais_atendimento/imprensa/notas-a-imprensa
traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#     100     try:
# --> 101         yield
#     102     except Exception as exc:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     135                     self._response_closed()
# --> 136             raise exc
#     137
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     105                     trailing_data,
# --> 106                 ) = self._receive_response_headers(**kwargs)
#     107                 trace.return_value = (
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     176         while True:
# --> 177             event = self._receive_event(timeout=timeout)
#     178             if isinstance(event, h11.Response):
#
# /usr/local/lib/python3.12/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     230                     msg = "Server disconnected without sending a response."
# --> 231                     raise RemoteProtocolError(msg)
#     232
#
# RemoteProtocolError: Server disconnected without sending a response.
#
# The above exception was the direct cause of the following exception:
#
# RemoteProtocolError                       Traceback (most recent call last)
# /tmp/ipykernel_314/14776.py in <cell line: 0>()
#      17 # beautifulsoap >> find e find_all
#      18 for pagina in paginas: # percorre cada pagina da string paginas
# ---> 19   pagina_inteira = acessa_pagina(pagina) # essa variavel esta armazenando o html da pagina (pagina inteira)
#      20   lista_noticias = pagina_inteira.find("div", attrs={"id": "content-core"}).find_all("article") # esta variavel string cria uma lista do elemento desejado (daqui em diante o codigo ira considerar apenas o que esta dentro do parametro que passamos)
#      21   for noticia in lista_noticias: # aqui o for percorre o elementos da lista anterior, entrando em cada uno dos intens achados pelo find
#
# /tmp/ipykernel_314/14776.py in acessa_pagina(link)
#      10 def acessa_pagina (link):
#      11   print (f"Estamos na pagina:{link}")
# ---> 12   pag_web = httpx.get(link, timeout=10.0)
#      13   bs = BeautifulSoup(pag_web.text, "html.parser")
#      14   return bs
#
# /usr/local/lib/python3.12/dist-packages/httpx/_api.py in get(url, params, headers, cookies, auth, proxy, follow_redirects, verify, timeout, trust_env)
#     193     on this function, as `GET` requests should not include a request body.
#     194     """
# --> 195     return request(
#     196         "GET",
#     197         url,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_api.py in request(method, url, params, content, data, files, json, headers, cookies, auth, proxy, timeout, follow_redirects, verify, trust_env)
#     107         trust_env=trust_env,
#     108     ) as client:
# --> 109         return client.request(
#     110             method=method,
#     111             url=url,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     823             extensions=extensions,
#     824         )
# --> 825         return self.send(request, auth=auth, follow_redirects=follow_redirects)
#     826
#     827     @contextmanager
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.12/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     247             extensions=request.extensions,
#     248         )
# --> 249         with map_httpcore_exceptions():
#     250             resp = self._pool.handle_request(req)
#     251
#
# /usr/lib/python3.12/contextlib.py in __exit__(self, typ, value, traceback)
#     156                 value = typ()
#     157             try:
# --> 158                 self.gen.throw(value)
#     159             except StopIteration as exc:
#     160                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/lib/python3.12/dist-packages/httpx/_transports/default.py in map_httpcore_exceptions()
#     116
#     117         message = str(exc)
# --> 118         raise mapped_exc(message) from exc
#     119
#     120
#
# RemoteProtocolError: Server disconnected without sending a response.

# %%
import httpx #web requests
from bs4 import BeautifulSoup #responsable to do the web scraping

# Lista de páginas para a Agência Gov
paginas = ["https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=0",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=20",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=40",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=60"]

def acessa_pagina(link):
  print(f"Estamos na pagina: {link}")
  try:
    pag_web = httpx.get(link, timeout=10.0)
    bs = BeautifulSoup(pag_web.text, "html.parser")
    return bs
  except Exception as e:
    print(f"Erro ao acessar {link}: {e}")
    return None

for pagina in paginas:
  pagina_inteira = acessa_pagina(pagina)
  if not pagina_inteira: continue

  # Na Agência Gov, as notícias ficam dentro de uma div com id='content-core' ou similar.
  # Vamos buscar as tags <article> diretamente para ser mais seguro.
  lista_noticias = pagina_inteira.find_all("article")

  for noticia in lista_noticias:
    # TÍTULO
    titulo_tag = noticia.find(attrs={"class": "titulo-noticia"})
    if titulo_tag:
        titulo = titulo_tag.text.strip()
        print(f"Título: {titulo}")

        # LINK
        #link_noticia = noticia.find("a")["href"]
        #print(f"Link: {link_noticia}")

        # DATA E HORÁRIO
        # No site da Agência Gov, data e hora costumam estar em spans com a classe 'data'
        #info_data = noticia.find("span", attrs={"class": "data"})
        #if info_data:
            #print(f"Data/Hora: {info_data.text.strip()}")
        #else:
            #print("Data/Hora não encontrada")

        #print("###\n")
# Out:
# Estamos na pagina: https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=0
# Título: Brasil passa a presidência do Brics para a Índia
# Estamos na pagina: https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=20
# Título: Líderes do Brics defendem multilateralismo e reforma da ONU em declaração da Cúpula
# Estamos na pagina: https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=40
# Título: Fórum Empresarial do Brics debate avanço da cooperação diante dos desafios globais
# Estamos na pagina: https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=60
# Título: Alckmin: desafios do Brics passam pela atuação dos parlamentos

# %%
import httpx #web requests
from bs4 import BeautifulSoup #responsable to do the web scraping (data colection)

# Variável e tipos de dados (string, lista, numero)
paginas = ["https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=0",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=20",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=40",
          "https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=60"]

def acessa_pagina (link):
  print (f"Estamos na pagina:{link}")
  pag_web = httpx.get(link, timeout=10.0)
  bs = BeautifulSoup(pag_web.text, "html.parser")
  return bs

# loop for
# beautifulsoap >> find e find_all
for pagina in paginas: # percorre cada pagina da string paginas
  pagina_inteira = acessa_pagina(pagina) # essa variavel esta armazenando o html da pagina (pagina inteira)
  lista_noticias = pagina_inteira.find("div", attrs={"id": "content"}).find_all("article") # esta variavel string cria uma lista do elemento desejado (daqui em diante o codigo ira considerar apenas o que esta dentro do parametro que passamos)
  for noticia in lista_noticias: # aqui o for percorre o elementos da lista anterior, entrando em cada uno dos intens achados pelo find
    #TÍTULO DA PÁGINA
    titulo = noticia.find(attrs={"class": "titulo-noticia"}).text.strip()
    print(titulo)

    #LINK DA NOTÍCIA
    #link_noticia = noticia.a["href"]
    #print(link_noticia)

    #DATA DA NOTÍCIA
    #data = noticia.find(attrs={"class": "summary-view-icon"}).text.strip()
    #print(data)

    #HORÁRIO DA NOTÍCIA


    #NÚMERO NOTA
    numero_da_nota = noticia.find("span", attrs={"class": "subtitle"}).text.strip()
    # o recurso .text.strip() retira a tag html deixando so o texto
# Out:
# Estamos na pagina:https://agenciagov.ebc.com.br/noticias/brics-brasil?b_start:int=0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_314/1027970993.py in <cell line: 0>()
#      18 for pagina in paginas: # percorre cada pagina da string paginas
#      19   pagina_inteira = acessa_pagina(pagina) # essa variavel esta armazenando o html da pagina (pagina inteira)
# ---> 20   lista_noticias = pagina_inteira.find("div", attrs={"id": "content"}).find_all("article") # esta variavel string cria uma lista do elemento desejado (daqui em diante o codigo ira considerar apenas o que esta dentro do parametro que passamos)
#      21   for noticia in lista_noticias: # aqui o for percorre o elementos da lista anterior, entrando em cada uno dos intens achados pelo find
#      22     #TÍTULO DA PÁGINA
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
